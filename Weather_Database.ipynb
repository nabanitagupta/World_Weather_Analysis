# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests

# %%
# Create 1500 random Latitude and Longitude Combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs) # the output is a zip object in memory
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Get nearest city from citipy module
# Use the tuple() function to display the latitude and longitude combinations
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# butaritari ki
# barentsburg sj
# khatanga ru
# airai pw
# atuona pf
# korla cn
# castro cl
# kapaa us
# sentyabrskiy ru
# chuy uy
# thompson ca
# saskylakh ru
# itaituba br
# ballina au
# rikitea pf
# harper lr
# ponta delgada pt
# acarau br
# cape town za
# bestwig de
# pila pl
# atar mr
# port macquarie au
# general pico ar
# ushuaia ar
# busselton au
# nome us
# shebunino ru
# cape town za
# letterkenny ie
# punta arenas cl
# barrow us
# sorland no
# amderma ru
# port alfred za
# sentyabrskiy ru
# belaya gora ru
# marcona pe
# port alfred za
# barrow us
# saint-philippe re
# jamestown sh
# puerto ayora ec
# punta arenas cl
# vaini to
# belushya guba ru
# barentsburg sj
# bluff nz
# cherskiy ru
# kulhudhuffushi mv
# barrow us
# meulaboh id
# hays us
# kargasok ru
# china mx
# upernavik gl
# malacacheta br
# rikitea pf
# qaanaaq gl
# rikitea pf
# rikitea pf
# rio claro tt
# monte alegre br
# georgetown sh
# leh in
# khatanga ru
# marfino ru
# grand gaube mu
# margate za
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Import the API key.
from config import New_Weather_Key_API

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + New_Weather_Key_API
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=42a987fcc8780ed6c0633150d301aaf8

# %%
# To test the code, create an endpoint URL for a city.
city_url = url + "&q=" + "Aberdeen"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=42a987fcc8780ed6c0633150d301aaf8&q=Aberdeen

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather2 = pd.DataFrame(city_weather["weather"])
        city_weather3 = list(city_weather2['description'])
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Rainfall in inches for the last three hours. 
        # If it is not raining, add 0 inches for the city
        try:
            city_rain = city_weather['rain']["3h"]
        except:
            city_rain = 0
        # Rainfall in inches for the last three hours. 
        # If it is not raining, add 0 inches for the city
        try:
            city_snow = city_weather['snow']["3h"]
        except:
            city_snow = 0
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather3,
                          "Rain inches (last 3hrs)": city_rain,
                          "Snow inches (last 3hrs)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | korla
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | itaituba
# Processing Record 14 of Set 1 | ballina
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | harper
# Processing Record 17 of Set 1 | ponta delgada
# Processing Record 18 of Set 1 | acarau
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | bestwig
# ...

# %%
len(city_data)
# Out:
# 558

# %%
city_data
# Out:
# [{'City': 'Butaritari',
#   'Country': 'KI',
#   'Date': '2020-03-20 23:10:37',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 83.25,
#   'Humidity': 79,
#   'Cloudiness': 47,
#   'Wind Speed': 16.78,
#   'Current Description': ['scattered clouds'],
#   'Rain inches (last 3hrs)': 0,
#   'Snow inches (last 3hrs)': 0},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Date': '2020-03-20 23:10:38',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': -15.57,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 15.79,
#   'Current Description': ['overcast clouds'],
#   'Rain inches (last 3hrs)': 0,
#   'Snow inches (last 3hrs)': 0},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Date': '2020-03-20 23:10:38',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 70.11,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Current Description': ['light rain'],
#   'Rain inches (last 3hrs)': 0.31,
#   'Snow inches (last 3hrs)': 0},
#  {'City': 'Atuona',
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head (10)
# Out:
#          City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 0  Butaritari      KI  2020-03-20 23:10:37   3.07  172.79     83.25        79
# 1    Khatanga      RU  2020-03-20 23:10:38  71.97  102.50    -15.57        92
# 2       Airai      TL  2020-03-20 23:10:38  -8.93  125.41     70.11        92
# 3      Atuona      PF  2020-03-20 23:10:38  -9.80 -139.03     81.99        80
# 4       Korla      CN  2020-03-20 23:10:38  41.76   86.15     34.83        39
# 5      Castro      BR  2020-03-20 23:07:48 -24.79  -50.01     63.63        96
# 6       Kapaa      US  2020-03-20 23:10:38  22.08 -159.32     82.40        78
# 7        Chuy      UY  2020-03-20 23:10:39 -33.70  -53.46     64.35        81
# 8    Thompson      CA  2020-03-20 23:10:23  55.74  -97.86     24.80        29
# 9   Saskylakh      RU  2020-03-20 23:10:39  71.92  114.08     -7.29        90
#
#    Cloudiness  Wind Speed Current Description  Rain inches (last 3hrs)  \
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
print(f"How many cities have recorded rainfall or snow?")
# Select rows with multiple condition. '|' stands for or. '!=' stands for not equal to
# Get the number of rows: len(df)
len(city_data_df[(city_data_df["Snow inches (last 3hrs)"] != 0) | (city_data_df["Rain inches (last 3hrs)"] != 0)])
# Out:
# How many cities have recorded rainfall or snow?
# 73
